# %%
students = [('jack', 34, 'Sydeny'),
            ('Riti', 30, 'Delhi'),
            ('Aadi', 16, 'New York'),
            ('Riti', 30, 'Delhi'),
            ('Riti', 30, 'Delhi'),
            ('Riti', 30, 'Mumbai'),
            ('Aadi', 40, 'London'),
            ('Sachin', 30, 'Delhi')
            ]

# %%
import pandas as pd
df_st=pd.DataFrame(students, columns=['Name', 'Age', 'City'])

# %%
df_st
# Out:
#      Name  Age      City
# 0    jack   34    Sydeny
# 1    Riti   30     Delhi
# 2    Aadi   16  New York
# 3    Riti   30     Delhi
# 4    Riti   30     Delhi
# 5    Riti   30    Mumbai
# 6    Aadi   40    London
# 7  Sachin   30     Delhi

# %%
df_st.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
df_st[df_st.duplicated()]
# Out:
#    Name  Age   City
# 3  Riti   30  Delhi
# 4  Riti   30  Delhi

# %%
df_st.drop_duplicates()
# Out:
#      Name  Age      City
# 0    jack   34    Sydeny
# 1    Riti   30     Delhi
# 2    Aadi   16  New York
# 5    Riti   30    Mumbai
# 6    Aadi   40    London
# 7  Sachin   30     Delhi

# %%
df_st
# Out:
#      Name  Age      City
# 0    jack   34    Sydeny
# 1    Riti   30     Delhi
# 2    Aadi   16  New York
# 3    Riti   30     Delhi
# 4    Riti   30     Delhi
# 5    Riti   30    Mumbai
# 6    Aadi   40    London
# 7  Sachin   30     Delhi

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pandas as pd

df_car=pd.read_excel(r'C:\Users\user\Desktop\Anastasios\Προσωπικά έγγραφα\EDU-Data Science\IBM Data Analyst Certificate\CarSalesByModelEnd.xlsx', engine='openpyxl')

# %%
df_car.head()
# Out:
#    Year    Month                       Date      Model  Dealer ID  \
# 0  2018  January 2018-01-01 23:00:00.000001   Beaufort       1222
# 1  2018  January 2018-01-01 23:00:00.000001     Salish       1222
# 2  2018  January 2018-01-01 23:00:00.000001   Labrador       1222
# 3  2018  January 2018-01-01 23:00:00.000001  Champlain       1222
# 4  2018  January 2018-01-01 23:00:00.000001     Hudson       1222
#
#    Quantity Sold   Profit
# 0             10  15000.0
# 1             13  39650.0
# 2             16  12800.0
# 3              3   6900.0
# 4             22  11000.0

# %%
bc_20203=pd.read_excel(r'C:\Users\user\Desktop\Anastasios\Προσωπικά έγγραφα\Καρναβάς\FB Bubble Cleaning\2020-3.xlsx', engine='openpyxl')

# %%
bc_20203.head()
# Out:
#         Date  Lifetime Total Likes  Daily New Likes  Daily Unlikes  \
# 0 2020-08-31                   894              NaN            1.0
# 1 2020-09-01                   894              NaN            NaN
# 2 2020-09-02                   894              NaN            NaN
# 3 2020-09-03                   894              NaN            NaN
# 4 2020-09-04                   894              NaN            NaN
#
#    Daily Page Engaged Users  Weekly Page Engaged Users  \
# 0                       NaN                        1.0
# 1                       NaN                        1.0
# 2                       NaN                        1.0
# 3                       NaN                        1.0
# 4                       NaN                        1.0
#
#    28 Days Page Engaged Users  Daily Total Reach  Weekly Total Reach  \
# 0                         1.0                3.0                 9.0
# 1                         1.0                NaN                 9.0
# ...

# %%
bc_20202=pd.read_excel(r'C:\Users\user\Desktop\Anastasios\Προσωπικά έγγραφα\Καρναβάς\FB Bubble Cleaning\2020-2.xlsx', engine='openpyxl')

# %%
bc_20201=pd.read_excel(r'C:\Users\user\Desktop\Anastasios\Προσωπικά έγγραφα\Καρναβάς\FB Bubble Cleaning\2020-1.xlsx', engine='openpyxl')

# %%
bc_20193=pd.read_excel(r'C:\Users\user\Desktop\Anastasios\Προσωπικά έγγραφα\Καρναβάς\FB Bubble Cleaning\2019-3.xlsx', engine='openpyxl')

# %%
bc_20192=pd.read_excel(r'C:\Users\user\Desktop\Anastasios\Προσωπικά έγγραφα\Καρναβάς\FB Bubble Cleaning\2019-2.xlsx', engine='openpyxl')

# %%
bc_20191=pd.read_excel(r'C:\Users\user\Desktop\Anastasios\Προσωπικά έγγραφα\Καρναβάς\FB Bubble Cleaning\2019-1.xlsx', engine='openpyxl')

# %%
bc_2019_2020=pd.concat([bc_20191,bc_20192,bc_20193,bc_20201,bc_20202,bc_20203])

# %%
bc_2019_2020.to_excel(r'C:\Users\user\Desktop\Anastasios\Προσωπικά έγγραφα\Καρναβάς\FB Bubble Cleaning\2019-2020.xlsx')

# %%
bc_19_20=pd.read_excel(r'C:\Users\user\Desktop\Anastasios\Προσωπικά έγγραφα\Καρναβάς\FB Bubble Cleaning\2019-2020 edited.xlsx', engine='openpyxl')

# %%
bc_19_20.head()
# Out:
#         Date Month-Year  Lifetime Total Likes  Daily New Likes (Page)  \
# 0 2019-01-01 2019-01-01                   NaN                     NaN
# 1 2019-01-02 2019-01-02                   NaN                     NaN
# 2 2019-01-03 2019-01-03                   NaN                     NaN
# 3 2019-01-04 2019-01-04                   NaN                     NaN
# 4 2019-01-05 2019-01-05                   NaN                     NaN
#
#    Daily Unlikes (Page)  Daily Page Engaged Users  Daily Total Reach (people)  \
# 0                   NaN                       NaN                         NaN
# 1                   NaN                       NaN                         NaN
# 2                   NaN                       NaN                         NaN
# 3                   NaN                       NaN                         NaN
# 4                   NaN                       NaN                         NaN
#
# ...

# %%
bc_19_20.shape
# Out:
# (731, 15)

# %%
import matplotlib.pyplot as plt

# %%
bc_19_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 15 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Date                                        730 non-null    datetime64[ns]
#  1   Lifetime Total Likes                        720 non-null    float64
#  2   Daily New Likes (Page)                      20 non-null     float64
#  3   Daily Unlikes (Page)                        27 non-null     float64
#  4   Daily Page Engaged Users                    123 non-null    float64
#  5   Daily Total Reach (people)                  259 non-null    float64
#  6   Daily Organic Reach                         238 non-null    float64
#  7   Daily Paid Reach                            9 non-null      float64
#  8   Daily Total Impressions (times)             259 non-null    float64
# ...

# %%
bc_19_20['Year']=bc_19_20['Date'].dt.year

# %%
bc_19_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 17 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Date                                        730 non-null    datetime64[ns]
#  1   Month-Year                                  730 non-null    datetime64[ns]
#  2   Lifetime Total Likes                        720 non-null    float64
#  3   Daily New Likes (Page)                      20 non-null     float64
#  4   Daily Unlikes (Page)                        27 non-null     float64
#  5   Daily Page Engaged Users                    123 non-null    float64
#  6   Daily Total Reach (people)                  259 non-null    float64
#  7   Daily Organic Reach                         238 non-null    float64
#  8   Daily Paid Reach                            9 non-null      float64
# ...

# %%
bc_19_20['Year'].isna().sum()
# Out:
# 1

# %%
import numpy as np

# %%
bc_19_20.loc[730, ['Year']]=2020

# %%
bc_19_20['Year']
# Out:
# 0      2019.0
# 1      2019.0
# 2      2019.0
# 3      2019.0
# 4      2019.0
#         ...
# 726    2020.0
# 727    2020.0
# 728    2020.0
# 729    2020.0
# 730    2020.0
# Name: Year, Length: 731, dtype: float64

# %%
bc_19_20['Year'].astype(int)
# Out:
# 0      2019
# 1      2019
# 2      2019
# 3      2019
# 4      2019
#        ...
# 726    2020
# 727    2020
# 728    2020
# 729    2020
# 730    2020
# Name: Year, Length: 731, dtype: int32

# %%
bc_19_20['Month']=bc_19_20['Date'].dt.month

# %%
bc_19_20.drop(bc_19_20.iloc[[730]].index, inplace=True)

# %%
bc_19_20.tail()
# Out:
#           Date Month-Year  Lifetime Total Likes  Daily New Likes (Page)  \
# 725 2020-12-26 2020-12-26                 898.0                     NaN
# 726 2020-12-27 2020-12-27                 898.0                     NaN
# 727 2020-12-28 2020-12-28                 898.0                     NaN
# 728 2020-12-29 2020-12-29                 898.0                     NaN
# 729 2020-12-30 2020-12-30                 898.0                     NaN
#
#      Daily Unlikes (Page)  Daily Page Engaged Users  \
# 725                   NaN                       NaN
# 726                   NaN                       NaN
# 727                   NaN                       NaN
# 728                   NaN                       NaN
# 729                   NaN                       NaN
#
#      Daily Total Reach (people)  Daily Organic Reach  Daily Paid Reach  \
# 725                         NaN                  NaN               NaN
# 726                         1.0                  1.0               NaN
# ...

# %%
bc_19_20['Year']=bc_19_20['Year'].astype(int)

# %%
bc_19_20['Month']=bc_19_20['Month'].astype(int)

# %%
bc_19_20.dtypes
# Out:
# Date                                          datetime64[ns]
# Month-Year                                    datetime64[ns]
# Lifetime Total Likes                                 float64
# Daily New Likes (Page)                               float64
# Daily Unlikes (Page)                                 float64
# Daily Page Engaged Users                             float64
# Daily Total Reach (people)                           float64
# Daily Organic Reach                                  float64
# Daily Paid Reach                                     float64
# Daily Total Impressions (times)                      float64
# Daily Organic impressions                            float64
# Daily Paid Impressions                               float64
# Daily Total Consumers                                float64
# Daily Page Consumptions                              float64
# Daily Negative Feedback (users)                      float64
# ...

# %%
bc_19_20.head()
# Out:
#         Date Month-Year  Lifetime Total Likes  Daily New Likes (Page)  \
# 0 2019-01-01 2019-01-01                   NaN                     NaN
# 1 2019-01-02 2019-01-02                   NaN                     NaN
# 2 2019-01-03 2019-01-03                   NaN                     NaN
# 3 2019-01-04 2019-01-04                   NaN                     NaN
# 4 2019-01-05 2019-01-05                   NaN                     NaN
#
#    Daily Unlikes (Page)  Daily Page Engaged Users  Daily Total Reach (people)  \
# 0                   NaN                       NaN                         NaN
# 1                   NaN                       NaN                         NaN
# 2                   NaN                       NaN                         NaN
# 3                   NaN                       NaN                         NaN
# 4                   NaN                       NaN                         NaN
#
# ...

# %%
bc_users=bc_19_20.groupby(['Year', 'Month'])[['Daily Page Engaged Users', 'Daily Total Reach (people)', 'Daily Total Impressions (times)']].sum()

# %%
bc_users
# Out:
#             Daily Page Engaged Users  Daily Total Reach (people)  \
# Year Month
# 2019 1                           0.0                         0.0
#      2                           0.0                         0.0
#      3                           1.0                         2.0
#      4                           2.0                         1.0
#      5                           1.0                         3.0
#      6                           1.0                         4.0
#      7                           0.0                         6.0
#      8                           1.0                         0.0
#      9                           0.0                         7.0
#      10                          2.0                         1.0
#      11                          1.0                         9.0
#      12                          0.0                         5.0
# 2020 1                           0.0                         5.0
# ...

# %%
bc_users=bc_users.reset_index()

# %%
bc_users
# Out:
#     Year  Month  Daily Page Engaged Users  Daily Total Reach (people)  \
# 0   2019      1                       0.0                         0.0
# 1   2019      2                       0.0                         0.0
# 2   2019      3                       1.0                         2.0
# 3   2019      4                       2.0                         1.0
# 4   2019      5                       1.0                         3.0
# 5   2019      6                       1.0                         4.0
# 6   2019      7                       0.0                         6.0
# 7   2019      8                       1.0                         0.0
# 8   2019      9                       0.0                         7.0
# 9   2019     10                       2.0                         1.0
# 10  2019     11                       1.0                         9.0
# 11  2019     12                       0.0                         5.0
# ...

# %%
bc_users.to_excel(r'C:\Users\user\Desktop\Anastasios\Προσωπικά έγγραφα\Καρναβάς\FB Bubble Cleaning\bc_users1.xlsx')

# %%
bc_users.plot('Month', 'Daily Page Engaged Users', kind='line')
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
fig, ax=plt.subplots()
ax.plot(bc_19_20['Daily Page Engaged Users'], bc_19_20['Date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1522         try:
# -> 1523             ret = self.converter.convert(x, self.units, self)
#    1524         except Exception as e:
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\matplotlib\dates.py in convert(value, unit, axis)
#    1895         """
# -> 1896         return date2num(value)
#    1897
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\matplotlib\dates.py in date2num(d)
#     429             d = np.asarray(d)
# --> 430         d = d.astype('datetime64[us]')
#     431
#
# ValueError: Error parsing datetime string "Total" at position 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
bc_19_20.plot('Date', 'Daily Page Engaged Users', kind='line', rot=45)
# Out:
# <AxesSubplot:xlabel='Date'>
